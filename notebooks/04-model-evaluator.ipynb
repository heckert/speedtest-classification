# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Model Evaluator is a helper class for visualizing model performance and comparing different models against each other.

# %%
import numpy as np
from src.utils.evaluation import ModelEvaluator

# %%
evaluator = ModelEvaluator()

# %%
y_true = np.array([0, 0, 1, 1, 1])

results = {
    'foo': (np.array([0, 0, 0, 0, 1])),
    'bar': (np.array([1, 0, 0, 1, 1])),
    'baz': (np.array([0, 0, 1, 1, 1])),
}

# %%
name = 'foo'

evaluator.get_summary(y_true, results[name], name=name)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.60         5
#    macro avg       0.75      0.67      0.58         5
# weighted avg       0.80      0.60      0.57         5

# %%
name = 'bar'

evaluator.get_summary(y_true, results[name], name=name)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.60         5
#    macro avg       0.58      0.58      0.58         5
# weighted avg       0.60      0.60      0.60         5

# %%
name = 'baz'

evaluator.get_summary(y_true, results[name], name=name)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %%
evaluator.plot()

# %%
evaluator.plot(type='macro', metric='precision')

# %%
evaluator.plot(type='macro', metric='recall')
